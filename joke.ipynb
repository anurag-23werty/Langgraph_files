# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_mistralai import ChatMistralAI
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatMistralAI(model="open-mistral-7b")

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Here’s a cheesy one for you:\n\n**Why did the pizza get a promotion?**\nBecause it had *too many layers*—and it was *always* in the *top 10*!\n\n*(Bonus groan: And now it’s *deliver*ing the best jokes in the city!)* 🍕😆',
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Here’s a cheesy one for you:\n\n**Why did the pizza get a promotion?**\nBecause it had *too many layers*—and it was *always* in the *top 10*!\n\n*(Bonus groan: And now it’s *deliver*ing the best jokes in the city!)* 🍕😆', 'explanation': 'Here’s a breakdown of the joke’s humor, layer by layer (pun intended):\n\n### **1. The Setup: "Why did the pizza get a promotion?"**\nThe joke starts with a classic *"Why did [X] [Y]?"* structure—a common format for simple, pun-based humor. The listener expects a clever or absurd answer, setting up a playful tone.\n\n### **2. The First Punchline: "Because it had *too many layers*—and it was *always* in the *top 10*!"**\nThis line plays on **double meanings**:\n   - **Literal Meaning**: Pizzas are made of layers (crust, cheese, sauce, toppings). If a pizza had "too many layers," it might be too complex or overstuffed—implying it was *too good* for its original role (e.g., a basic slice).\n   - **Punny Me
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Here’s a cheesy one for you:\n\n**Why did the pizza get a promotion?**\nBecause it had *too many layers*—and it was *always* in the *top 10*!\n\n*(Bonus groan: And now it’s *deliver*ing the best jokes in the city!)* 🍕😆', 'explanation': 'Here’s a breakdown of the joke’s humor, layer by layer (pun intended):\n\n### **1. The Setup: "Why did the pizza get a promotion?"**\nThe joke starts with a classic *"Why did [X] [Y]?"* structure—a common format for simple, pun-based humor. The listener expects a clever or absurd answer, setting up a playful tone.\n\n### **2. The First Punchline: "Because it had *too many layers*—and it was *always* in the *top 10*!"**\nThis line plays on **double meanings**:\n   - **Literal Meaning**: Pizzas are made of layers (crust, cheese, sauce, toppings). If a pizza had "too many layers," it might be too complex or overstuffed—implying it was *too good* for its original role (e.g., a basic slice).\n   - **Punny M
# ...

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Here’s a pasta pun for you:\n\n**Why did the pasta break up with the salad?**\nBecause it couldn’t handle the *lettuce* it was dealing with!\n\n*(Bonus groan: And now they’re just *spaghetti* together.)* 😆🍝',
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Here’s a cheesy one for you:\n\n**Why did the pizza get a promotion?**\nBecause it had *too many layers*—and it was *always* in the *top 10*!\n\n*(Bonus groan: And now it’s *deliver*ing the best jokes in the city!)* 🍕😆', 'explanation': 'Here’s a breakdown of the joke’s humor, layer by layer (pun intended):\n\n### **1. The Setup: "Why did the pizza get a promotion?"**\nThe joke starts with a classic *"Why did [X] [Y]?"* structure—a common format for simple, pun-based humor. The listener expects a clever or absurd answer, setting up a playful tone.\n\n### **2. The First Punchline: "Because it had *too many layers*—and it was *always* in the *top 10*!"**\nThis line plays on **double meanings**:\n   - **Literal Meaning**: Pizzas are made of layers (crust, cheese, sauce, toppings). If a pizza had "too many layers," it might be too complex or overstuffed—implying it was *too good* for its original role (e.g., a basic slice).\n   - **Punny Me
# ...

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Here’s a cheesy one for you:\n\n**Why did the pizza get a promotion?**\nBecause it had *too many layers*—and it was *always* in the *top 10*!\n\n*(Bonus groan: And now it’s *deliver*ing the best jokes in the city!)* 🍕😆', 'explanation': 'Here’s a breakdown of the joke’s humor, layer by layer (pun intended):\n\n### **1. The Setup: "Why did the pizza get a promotion?"**\nThe joke starts with a classic *"Why did [X] [Y]?"* structure—a common format for simple, pun-based humor. The listener expects a clever or absurd answer, setting up a playful tone.\n\n### **2. The First Punchline: "Because it had *too many layers*—and it was *always* in the *top 10*!"**\nThis line plays on **double meanings**:\n   - **Literal Meaning**: Pizzas are made of layers (crust, cheese, sauce, toppings). If a pizza had "too many layers," it might be too complex or overstuffed—implying it was *too good* for its original role (e.g., a basic slice).\n   - **Punny M
# ...

# %%
workflow.get_state({"configurable": {"thread_id": "1", "checkpoint_id":'1f170cc0-342c-6e3e-8001-dc9dc9d75182' }})
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Here’s a cheesy one for you:\n\n**Why did the pizza get a promotion?**\nBecause it had *too many layers*—and it was *always* in the *top 10*!\n\n*(Bonus groan: And now it’s *deliver*ing the best jokes in the city!)* 🍕😆'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f170cc0-342c-6e3e-8001-dc9dc9d75182'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-06-25T19:28:15.554463+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f170cc0-1b9d-6ecc-8000-c03e70c9c0f8'}}, tasks=(PregelTask(id='6857c638-a01e-0495-4d23-074e9f5e4ed6', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'Here’s a breakdown of the joke’s humor, layer by layer (pun intended):\n\n### **1. The Setup: "Why did the pizza get a promotion?"**\nThe joke starts with a cla
# ...

# %%
workflow.invoke(None, {"configurable": {"thread_id": "1", "checkpoint_id":'1f170cc0-342c-6e3e-8001-dc9dc9d75182' }})
# Out:
# {'topic': 'pizza',
#  'joke': 'Here’s a cheesy one for you:\n\n**Why did the pizza get a promotion?**\nBecause it had *too many layers*—and it was *always* in the *top 10*!\n\n*(Bonus groan: And now it’s *deliver*ing the best jokes in the city!)* 🍕😆',
# ...
